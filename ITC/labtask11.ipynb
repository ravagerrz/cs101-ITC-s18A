# %%
import os
with open ('file.txt','r') as myfile:
    var = 0
    #reader = csv.reader(myfile)
    for row in myfile:
        print (row)
        
        #for i in row:
            #a = int(i)
            #var = var + a
        #print var
# Out:
# 123

# %%
import csv
with open ('file.txt','r') as myfile:
    with open('file1.csv','w+') as f:
        writer = csv.writer(f)
        for row in myfile:
            writer.writerow([row[0],row[2],row[1],int(row[0]) + int(row [1]) + int(row[2])])
        f.seek(0)
        for r in f:
            print r
# Out:
# 1,3,2,6

# %%
with open('airpot.csv','r') as plane:
    reader = csv.reader(plane)
    for i in reader:
        if (i[3] == "Australia") or (i[3] == "Russia"):
            print i[3],"=",i[1]
        else:
            continue
# Out:
# Russia = Yakutsk Airport
# Russia = Mirny Airport
# Russia = Ignatyevo Airport
# Russia = Khabarovsk-Novy Airport
# Russia = Provideniya Bay Airport
# Russia = Sokol Airport
# Russia = Pevek Airport
# Russia = Yelizovo Airport
# Russia = Yuzhno-Sakhalinsk Airport
# Russia = Vladivostok International Airport
# Russia = Chita-Kadala Airport
# Russia = Bratsk Airport
# Russia = Irkutsk Airport
# Russia = Ulan-Ude Airport (Mukhino)
# Russia = Pulkovo Airport
# Russia = Murmansk Airport
# Russia = Khrabrovo Airport
# Russia = Abakan Airport
# Russia = Barnaul Airport
# Russia = Kemerovo Airport
# Russia = Omsk Central Airport
# Russia = Krasnodar Pashkovsky International Airport
# Russia = Uytash Airport
# Russia = Mineralnyye Vody Airport
# Russia = Stavropol Shpakovskoye Airport
# Russia = Rostov-on-Don Airport
# Russia = Sochi International Airport
# Russia = Astrakhan Airport
# Russia = Volgograd International Airport
# Russia = Chelyabinsk Balandino Airport
# ...

# %%
with open('airpot.csv','r') as plane:
    longitude={}
    reader = csv.reader(plane)
    for i in reader:
        a = i[0]
        longitude[a] = i[6] 
    print longitude
# Out:
# {'5989': '21.21100044', '6797': '47.3849983215', '6794': '-31.8885993958', '6795': '48.13570022583008', '6792': '-29.7593994140625', '6793': '-33.3816986084', '6790': '34.86920166015625', '6791': '13.361000061035156', '6798': '53.053890228271484', '6799': '48.446389', '270': '12.047599792480469', '271': '11.855299949645996', '272': '7.7038798332214355', '273': '6.5773701667785645', '274': '9.652170181274414', '275': '5.0154900550842285', '276': '12.916299819946289', '277': '9.257550239562988', '278': '11.130200386047363', '279': '13.5024995803833', '12019': '-34.6239013671875', '12018': '-36.18280029296875', '12015': '-29.973899841308594', '12014': '-34.623600006103516', '12017': '-35.99470138549805', '12016': '-33.70970153808594', '12011': '-23.646099', '12010': '52.297316667', '12013': '-36.55189895629883', '12012': '-37.30939865112305', '9528': '1.04278004169', '9255': '59.397499', '9252': '29.1086006165', '9253': '49.97439956665039', '9251': '38.72140121', '3519': '36.668598175',
# ...

# %%
with open('airpot.csv','r') as plane:
    altitude={}
    reader = csv.reader(plane)
    for k in reader:
        b = k[0]
        altitude[b] = k[7] 
    print altitude
# Out:
# {'5989': '-156.973999', '6797': '9.69999980927', '6794': '152.514007568', '6795': '114.64600372314453', '6792': '153.02999877929688', '6793': '149.132995605', '6790': '48.5525016784668', '6791': '121.82599639892578', '6798': '9.208610534667969', '6799': '15.634167', '270': '8.524620056152344', '271': '13.080900192260742', '272': '8.613940238952637', '273': '3.321160078048706', '274': '6.462259769439697', '275': '6.94959020614624', '276': '5.207190036773682', '277': '12.430399894714355', '278': '7.685810089111328', '279': '7.1267499923706055', '12019': '148.0279998779297', '12018': '147.88800048828125', '12015': '146.81700134277344', '12014': '143.5780029296875', '12017': '146.35699462890625', '12016': '136.5050048828125', '12011': '146.584', '12010': '43.7241', '12013': '146.0070037841797', '12012': '142.98899841308594', '9528': '-50.516700744599994', '9255': '11.3469', '9252': '-95.462097168', '9253': '14.178099632263184', '9251': '-77.51540375', '3519': '-87.49620056150002', '3518'
# ...
